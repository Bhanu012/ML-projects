# %% [markdown]
# Import pandas library to clean the data.

# %%
import pandas as pd

# %%
cd C:\Users\rbhan\Downloads
# Out:
# C:\Users\rbhan\Downloads

# %%
data=pd.read_excel(r"ML Live Flight Fare Resourses16963295320 (1).xlsx")

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# #For reducing the data size we drop the 2 unusual column. It is calling Feature Selection.

# %% [markdown]
# drop some columns to reduce the Redundancy of the data.

# %%
data.drop(["Additional_Info","Route"],axis=1,inplace=True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price
# 0      01:10 22 Mar   2h 50m    non-stop   3897
# 1             13:15   7h 25m     2 stops   7662
# ...

# %% [markdown]
# #Now remove the null values and replace it is called data cleaning.

# %%
data.isnull().any()
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops         True
# Price              False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Price              0
# dtype: int64

# %%
data[data["Total_Stops"].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Dep_Time  Arrival_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin    09:45  09:25 07 May
#
#      Duration Total_Stops  Price
# 9039  23h 40m         NaN   7480

# %%
data[data["Total_Stops"].isnull()].index
# Out:
# Index([9039], dtype='int64')

# %%
data.drop([9039],inplace=True)

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Price              0
# dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Date_of_Journey  10682 non-null  object
#  2   Source           10682 non-null  object
#  3   Destination      10682 non-null  object
#  4   Dep_Time         10682 non-null  object
#  5   Arrival_Time     10682 non-null  object
#  6   Duration         10682 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Price            10682 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 834.5+ KB

# %%
pd.to_datetime(data["Date_of_Journey"]).dt.year.unique()
# Out:
# array([2019])

# %%
data["date"]=pd.to_datetime(data["Date_of_Journey"]).dt.day
data["month"]=pd.to_datetime(data["Date_of_Journey"]).dt.month

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price  date  month
# 0      01:10 22 Mar   2h 50m    non-stop   3897    24      3
# ...

# %%
data.drop(["Date_of_Journey"],axis=1,inplace=True)

# %%
data
# Out:
#            Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0           IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1        Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2      Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun      19h
# 3           IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4           IndiGo  Banglore   New Delhi    16:50         21:35   4h 45m
# ...            ...       ...         ...      ...           ...      ...
# 10678     Air Asia   Kolkata    Banglore    19:55         22:25   2h 30m
# 10679    Air India   Kolkata    Banglore    20:45         23:20   2h 35m
# 10680  Jet Airways  Banglore       Delhi    08:20         11:20       3h
# 10681      Vistara  Banglore   New Delhi    11:30         14:10   2h 40m
# 10682    Air India     Delhi      Cochin    10:55         19:15   8h 20m
#
#       Total_Stops  Price  date  month
# 0        non-stop   3897    24      3
# ...

# %%
data["d_hour"]=pd.to_datetime(data["Dep_Time"]).dt.hour
data["d_minute"]=pd.to_datetime(data["Dep_Time"]).dt.minute
data["a_hour"]=pd.to_datetime(data["Arrival_Time"]).dt.hour
data["a_minute"]=pd.to_datetime(data["Arrival_Time"]).dt.minute

# %%
data
# Out:
#            Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0           IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1        Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2      Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun      19h
# 3           IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4           IndiGo  Banglore   New Delhi    16:50         21:35   4h 45m
# ...            ...       ...         ...      ...           ...      ...
# 10678     Air Asia   Kolkata    Banglore    19:55         22:25   2h 30m
# 10679    Air India   Kolkata    Banglore    20:45         23:20   2h 35m
# 10680  Jet Airways  Banglore       Delhi    08:20         11:20       3h
# 10681      Vistara  Banglore   New Delhi    11:30         14:10   2h 40m
# 10682    Air India     Delhi      Cochin    10:55         19:15   8h 20m
#
#       Total_Stops  Price  date  month  d_hour  d_minute  a_hour  a_minute
# ...

# %%
lis=data["Duration"]

# %%
new_lis=[]
for i in lis:
    if len(i.split(" "))==1:
        if "m" in i:
            i="0h "+i
        else:
            i=i+" 0m"
    new_lis.append(i)

# %%
data["Duration"]=new_lis

# %%
data
# Out:
#            Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0           IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1        Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2      Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun   19h 0m
# 3           IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4           IndiGo  Banglore   New Delhi    16:50         21:35   4h 45m
# ...            ...       ...         ...      ...           ...      ...
# 10678     Air Asia   Kolkata    Banglore    19:55         22:25   2h 30m
# 10679    Air India   Kolkata    Banglore    20:45         23:20   2h 35m
# 10680  Jet Airways  Banglore       Delhi    08:20         11:20    3h 0m
# 10681      Vistara  Banglore   New Delhi    11:30         14:10   2h 40m
# 10682    Air India     Delhi      Cochin    10:55         19:15   8h 20m
#
#       Total_Stops  Price  date  month  d_hour  d_minute  a_hour  a_minute
# ...

# %%
data["dur_h"]=data["Duration"].str.split(" ").str[0].replace(["h"],"",regex=True)
data["dur_m"]=data["Duration"].str.split(" ").str[1].replace(["m"],"",regex=True)

# %%
data
# Out:
#            Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0           IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1        Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2      Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun   19h 0m
# 3           IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4           IndiGo  Banglore   New Delhi    16:50         21:35   4h 45m
# ...            ...       ...         ...      ...           ...      ...
# 10678     Air Asia   Kolkata    Banglore    19:55         22:25   2h 30m
# 10679    Air India   Kolkata    Banglore    20:45         23:20   2h 35m
# 10680  Jet Airways  Banglore       Delhi    08:20         11:20    3h 0m
# 10681      Vistara  Banglore   New Delhi    11:30         14:10   2h 40m
# 10682    Air India     Delhi      Cochin    10:55         19:15   8h 20m
#
#       Total_Stops  Price  date  month  d_hour  d_minute  a_hour  a_minute  \
# ...

# %%
data.drop(["Dep_Time","Arrival_Time","Duration"],axis=1,inplace=True)

# %%
data
# Out:
#            Airline    Source Destination Total_Stops  Price  date  month  \
# 0           IndiGo  Banglore   New Delhi    non-stop   3897    24      3
# 1        Air India   Kolkata    Banglore     2 stops   7662     1      5
# 2      Jet Airways     Delhi      Cochin     2 stops  13882     9      6
# 3           IndiGo   Kolkata    Banglore      1 stop   6218    12      5
# 4           IndiGo  Banglore   New Delhi      1 stop  13302     1      3
# ...            ...       ...         ...         ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore    non-stop   4107     9      4
# 10679    Air India   Kolkata    Banglore    non-stop   4145    27      4
# 10680  Jet Airways  Banglore       Delhi    non-stop   7229    27      4
# 10681      Vistara  Banglore   New Delhi    non-stop  12648     1      3
# 10682    Air India     Delhi      Cochin     2 stops  11753     9      5
#
#        d_hour  d_minute  a_hour  a_minute dur_h dur_m
# ...

# %%
data["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
data["Total_Stops"].replace(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],[0,2,1,3,4],inplace=True)

# %% [markdown]
# Encode the data so we use the data into models

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Price', 'date',
#        'month', 'd_hour', 'd_minute', 'a_hour', 'a_minute', 'dur_h', 'dur_m'],
#       dtype='object')

# %%
data[['Airline', 'Source', 'Destination']]=data[['Airline', 'Source', 'Destination']].apply(enc.fit_transform)

# %%
data
# Out:
#        Airline  Source  Destination  Total_Stops  Price  date  month  d_hour  \
# 0            3       0            5            0   3897    24      3      22
# 1            1       3            0            2   7662     1      5       5
# 2            4       2            1            2  13882     9      6       9
# 3            3       3            0            1   6218    12      5      18
# 4            3       0            5            1  13302     1      3      16
# ...        ...     ...          ...          ...    ...   ...    ...     ...
# 10678        0       3            0            0   4107     9      4      19
# 10679        1       3            0            0   4145    27      4      20
# 10680        4       0            2            0   7229    27      4       8
# 10681       10       0            5            0  12648     1      3      11
# 10682        1       2            1            2  11753     9      5      10
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Airline      10682 non-null  int32
#  1   Source       10682 non-null  int32
#  2   Destination  10682 non-null  int32
#  3   Total_Stops  10682 non-null  int64
#  4   Price        10682 non-null  int64
#  5   date         10682 non-null  int32
#  6   month        10682 non-null  int32
#  7   d_hour       10682 non-null  int32
#  8   d_minute     10682 non-null  int32
#  9   a_hour       10682 non-null  int32
#  10  a_minute     10682 non-null  int32
#  11  dur_h        10682 non-null  object
#  12  dur_m        10682 non-null  object
# dtypes: int32(9), int64(2), object(2)
# memory usage: 792.8+ KB

# %%
data[["dur_h","dur_m"]]=data[["dur_h","dur_m"]].astype(int)

# %% [markdown]
# Apply the linear model on the dataset to find the model accuracy so we can predict the value

# %%
x=data.drop("Price",axis=1)
y=data["Price"]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
model.score(x_train,y_train)
# Out:
# 0.43756924788280527

# %%
model.score(x_test,y_test)
# Out:
# 0.4320828221684547

# %% [markdown]
# Try to find the accuracy using different models of regression.

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
lis1=[DecisionTreeRegressor,KNeighborsRegressor,RandomForestRegressor,GradientBoostingRegressor]

# %%
for i in lis1:
    model=i()
    model.fit(x_train,y_train)
    print(i)
    print(model.score(x_train,y_train))
    print(model.score(x_test,y_test))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.9711683243930616
# 0.6216359616111486
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# 0.7676672382023035
# 0.5674544873466076
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.9538471913406421
# 0.7907267742015218
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# 0.7848997907857425
# 0.7498836333289777

# %%
from sklearn.model_selection import KFold ,cross_val_score

# %%
kf=KFold(n_splits=6)

# %%
score=[]
for i in lis1:
    score.append(cross_val_score(i(),x,y,cv=kf))

# %%
score
# Out:
# [array([0.67574238, 0.74582741, 0.69904745, 0.70480844, 0.70305821,
#         0.68149389]),
#  array([0.59281226, 0.62175138, 0.6543957 , 0.5835637 , 0.61809717,
#         0.64346007]),
#  array([0.81856899, 0.79788797, 0.82762578, 0.80197939, 0.80975668,
#         0.7578553 ]),
#  array([0.75334525, 0.75164311, 0.78559729, 0.76866994, 0.77260566,
#         0.78451412])]

# %%
import numpy as np

# %%
for i in range(len(score)):
    print(lis1[i])
    print(score[i].mean())
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.7016629623561417
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# 0.6190133795613851
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.8022790158559804
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# 0.7693958938702932

# %%
rf=RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimator=[400,500,600,700,800,900,1000]
n_depth=[2,3,4,5]
random=[10,20,30,40]
criteria=["sqaured","absolute_error"]

# %%
dic={"n_estimators":n_estimator,"max_depth":n_depth,"random_state":random,"criterion":criteria}

# %%
grid_search=RandomizedSearchCV(estimator=RandomForestRegressor(),param_distributions=dic,scoring="neg_mean_squared_error",n_iter=20,n_jobs=2)

# %%
grid_search.fit(x,y)

# %%
grid_search.best
