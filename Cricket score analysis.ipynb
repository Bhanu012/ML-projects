# %%
import pandas as pd

# %%
cd C:\Users\rbhan\Downloads
# Out:
# C:\Users\rbhan\Downloads

# %%
data=pd.read_excel(r"espn cric score.xlsx")

# %%
data
# Out:
#    Records for Test Matches Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                       NaN        NaN        NaN        NaN        NaN
# 1          Highest averages        NaN        NaN        NaN        NaN
# 2                    Player       Span        Mat       Inns         NO
# 3          DG Bradman (AUS)  1928-1948         52         80         10
# 4            HC Brook (ENG)  2022-2023         12         20          1
# ..                      ...        ...        ...        ...        ...
# 60         KD Walters (AUS)  1965-1981         74        125         14
# 61        GC Smith (ICC/SA)  2002-2014        117        205         13
# 62        WH Ponsford (AUS)  1924-1934         29         48          4
# 63          SJ McCabe (AUS)  1930-1938         39         62          5
# 64         DR Jardine (ENG)  1928-1934         22         33          6
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# ...

# %%
data.drop([0,1],inplace=True)

# %%
data
# Out:
#    Records for Test Matches Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2                    Player       Span        Mat       Inns         NO
# 3          DG Bradman (AUS)  1928-1948         52         80         10
# 4            HC Brook (ENG)  2022-2023         12         20          1
# 5            AC Voges (AUS)  2015-2016         20         31          7
# 6           RG Pollock (SA)  1963-1970         23         41          4
# ..                      ...        ...        ...        ...        ...
# 60         KD Walters (AUS)  1965-1981         74        125         14
# 61        GC Smith (ICC/SA)  2002-2014        117        205         13
# 62        WH Ponsford (AUS)  1924-1934         29         48          4
# 63          SJ McCabe (AUS)  1930-1938         39         62          5
# 64         DR Jardine (ENG)  1928-1934         22         33          6
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# ...

# %%
data.columns=data.loc[2]

# %%
data.loc[2]
# Out:
# 2
# Player    Player
# Span        Span
# Mat          Mat
# Inns        Inns
# NO            NO
# Runs        Runs
# HS            HS
# Ave          Ave
# BF            BF
# SR            SR
# 100.0      100.0
# 50.0        50.0
# 0.0          0.0
# 4s            4s
# 6s            6s
# Name: 2, dtype: object

# %%
data.columns=['Player',   'Span',    'Mat',   'Inns',     'NO',   'Runs',     'HS',
          'Ave',     'BF',     'SR',    100.0,     50.0,      0.0,     '4s',
           '6s']

# %%
data
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 2              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF
# 3    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 4      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 5      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 6     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127     48  2110+
#
#        SR  100.0  50.0   0.0    4s  6s
# 2      SR  100.0  50.0   0.0    4s  6s
# ...

# %%
data.drop(2,inplace=True)

# %%
data
# Out:
#                Player       Span  Mat Inns  NO  Runs    HS    Ave     BF  \
# 3    DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94  9800+
# 4      HC Brook (ENG)  2022-2023   12   20   1  1181   186  62.15   1287
# 5      AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87   2667
# 6     RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97  1707+
# 7     GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83   416+
# ..                ...        ...  ...  ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22   33   6  1296   127     48  2110+
#
#        SR  100.0  50.0   0.0    4s  6s
# 3    58.6   29.0  13.0   7.0  626+   6
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#     index             Player       Span  Mat Inns  NO  Runs    HS    Ave  \
# 0       3   DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94
# 1       4     HC Brook (ENG)  2022-2023   12   20   1  1181   186  62.15
# 2       5     AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87
# 3       6    RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97
# 4       7    GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83
# ..    ...                ...        ...  ...  ...  ..   ...   ...    ...
# 57     60   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26
# 58     61  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25
# 59     62  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22
# 60     63    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21
# 61     64   DR Jardine (ENG)  1928-1934   22   33   6  1296   127     48
#
#        BF     SR  100.0  50.0   0.0    4s  6s
# ...

# %%
data.drop("index",axis=1,inplace=True)

# %%
data
# Out:
#                Player       Span  Mat Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12   20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83   416+
# ..                ...        ...  ...  ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22   33   6  1296   127     48  2110+
#
#        SR  100.0  50.0   0.0    4s  6s
# 0    58.6   29.0  13.0   7.0  626+   6
# ...

# %%
data["Country"]=data["Player"].str.split("(").str[1].str.split(")").str[0]

# %%
data
# Out:
#                Player       Span  Mat Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12   20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83   416+
# ..                ...        ...  ...  ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22   33   6  1296   127     48  2110+
#
#        SR  100.0  50.0   0.0    4s  6s Country
# ...

# %%
data["Name"]=data["Player"].str.split("(").str[0]

# %%
data
# Out:
#                Player       Span  Mat Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12   20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83   416+
# ..                ...        ...  ...  ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22   33   6  1296   127     48  2110+
#
#        SR  100.0  50.0   0.0    4s  6s Country          Name
# ...

# %%
data.drop("Player",axis=1,inplace=True)

# %%
data
# Out:
#          Span  Mat Inns  NO  Runs    HS    Ave     BF     SR  100.0  50.0  \
# 0   1928-1948   52   80  10  6996   334  99.94  9800+   58.6   29.0  13.0
# 1   2022-2023   12   20   1  1181   186  62.15   1287  91.76    4.0   7.0
# 2   2015-2016   20   31   7  1485  269*  61.87   2667  55.68    5.0   4.0
# 3   1963-1970   23   41   4  2256   274  60.97  1707+  54.48    7.0  11.0
# 4   1930-1954   22   40   4  2190  270*  60.83   416+     56   10.0   5.0
# ..        ...  ...  ...  ..   ...   ...    ...    ...    ...    ...   ...
# 57  1965-1981   74  125  14  5357   250  48.26  8662+  49.16   15.0  33.0
# 58  2002-2014  117  205  13  9265   277  48.25  15525  59.67   27.0  38.0
# 59  1924-1934   29   48   4  2122   266  48.22  3118+  44.77    7.0   6.0
# 60  1930-1938   39   62   5  2748   232  48.21  3217+  60.02    6.0  13.0
# 61  1928-1934   22   33   6  1296   127     48  2110+  25.59    1.0  10.0
#
#      0.0    4s  6s Country          Name
# ...

# %%
data["Start_Date"]=data["Span"].str.split("-").str[0]
data["End_Date"]=data["Span"].str.split("-").str[1]
data
# Out:
#          Span  Mat Inns  NO  Runs    HS    Ave     BF     SR  100.0  50.0  \
# 0   1928-1948   52   80  10  6996   334  99.94  9800+   58.6   29.0  13.0
# 1   2022-2023   12   20   1  1181   186  62.15   1287  91.76    4.0   7.0
# 2   2015-2016   20   31   7  1485  269*  61.87   2667  55.68    5.0   4.0
# 3   1963-1970   23   41   4  2256   274  60.97  1707+  54.48    7.0  11.0
# 4   1930-1954   22   40   4  2190  270*  60.83   416+     56   10.0   5.0
# ..        ...  ...  ...  ..   ...   ...    ...    ...    ...    ...   ...
# 57  1965-1981   74  125  14  5357   250  48.26  8662+  49.16   15.0  33.0
# 58  2002-2014  117  205  13  9265   277  48.25  15525  59.67   27.0  38.0
# 59  1924-1934   29   48   4  2122   266  48.22  3118+  44.77    7.0   6.0
# 60  1930-1938   39   62   5  2748   232  48.21  3217+  60.02    6.0  13.0
# 61  1928-1934   22   33   6  1296   127     48  2110+  25.59    1.0  10.0
#
#      0.0    4s  6s Country          Name Start_Date End_Date
# ...

# %%
data.drop("Span",axis=1,inplace=True)

# %%
data
# Out:
#     Mat Inns  NO  Runs    HS    Ave     BF     SR  100.0  50.0   0.0    4s  \
# 0    52   80  10  6996   334  99.94  9800+   58.6   29.0  13.0   7.0  626+
# 1    12   20   1  1181   186  62.15   1287  91.76    4.0   7.0   1.0   141
# 2    20   31   7  1485  269*  61.87   2667  55.68    5.0   4.0   2.0   186
# 3    23   41   4  2256   274  60.97  1707+  54.48    7.0  11.0   1.0  246+
# 4    22   40   4  2190  270*  60.83   416+     56   10.0   5.0   2.0  104+
# ..  ...  ...  ..   ...   ...    ...    ...    ...    ...   ...   ...   ...
# 57   74  125  14  5357   250  48.26  8662+  49.16   15.0  33.0   4.0  525+
# 58  117  205  13  9265   277  48.25  15525  59.67   27.0  38.0  11.0  1165
# 59   29   48   4  2122   266  48.22  3118+  44.77    7.0   6.0   1.0  119+
# 60   39   62   5  2748   232  48.21  3217+  60.02    6.0  13.0   4.0  241+
# 61   22   33   6  1296   127     48  2110+  25.59    1.0  10.0   2.0   53+
#
#     6s Country          Name Start_Date End_Date
# ...

# %%
data.columns
# Out:
# Index([       'Mat',       'Inns',         'NO',       'Runs',         'HS',
#               'Ave',         'BF',         'SR',        100.0,         50.0,
#                 0.0,         '4s',         '6s',    'Country',       'Name',
#        'Start_Date',   'End_Date'],
#       dtype='object')

# %%
data=data[['Name', 'Country',  'Start_Date',   'End_Date' , 'Mat',       'Inns',         'NO',       'Runs',         'HS',
              'Ave',         'BF',         'SR',        100.0,         50.0,
                0.0,         '4s',         '6s']]

# %%
data
# Out:
#             Name Country Start_Date End_Date  Mat Inns  NO  Runs    HS    Ave  \
# 0    DG Bradman      AUS       1928     1948   52   80  10  6996   334  99.94
# 1      HC Brook      ENG       2022     2023   12   20   1  1181   186  62.15
# 2      AC Voges      AUS       2015     2016   20   31   7  1485  269*  61.87
# 3    RG Pollock       SA       1963     1970   23   41   4  2256   274  60.97
# 4    GA Headley       WI       1930     1954   22   40   4  2190  270*  60.83
# ..           ...     ...        ...      ...  ...  ...  ..   ...   ...    ...
# 57   KD Walters      AUS       1965     1981   74  125  14  5357   250  48.26
# 58     GC Smith   ICC/SA       2002     2014  117  205  13  9265   277  48.25
# 59  WH Ponsford      AUS       1924     1934   29   48   4  2122   266  48.22
# 60    SJ McCabe      AUS       1930     1938   39   62   5  2748   232  48.21
# 61   DR Jardine      ENG       1928     1934   22   33   6  1296   127     48
#
# ...

# %%
data[["HS","BF","4s","6s"]]=data[["HS","BF","4s","6s"]].replace("[+*]","",regex=True)

# %%
data
# Out:
#             Name Country Start_Date End_Date  Mat Inns  NO  Runs   HS    Ave  \
# 0    DG Bradman      AUS       1928     1948   52   80  10  6996  334  99.94
# 1      HC Brook      ENG       2022     2023   12   20   1  1181  186  62.15
# 2      AC Voges      AUS       2015     2016   20   31   7  1485  269  61.87
# 3    RG Pollock       SA       1963     1970   23   41   4  2256  274  60.97
# 4    GA Headley       WI       1930     1954   22   40   4  2190  270  60.83
# ..           ...     ...        ...      ...  ...  ...  ..   ...  ...    ...
# 57   KD Walters      AUS       1965     1981   74  125  14  5357  250  48.26
# 58     GC Smith   ICC/SA       2002     2014  117  205  13  9265  277  48.25
# 59  WH Ponsford      AUS       1924     1934   29   48   4  2122  266  48.22
# 60    SJ McCabe      AUS       1930     1938   39   62   5  2748  232  48.21
# 61   DR Jardine      ENG       1928     1934   22   33   6  1296  127     48
#
# ...

# %%
data[["Mat"]]=data[["Mat"]].replace("[+*]","",regex=True)

# %%
data[["BF","SR"]]=data[["BF","SR"]].replace("-",0)

# %%
data.columns
# Out:
# Index([      'Name',    'Country', 'Start_Date',   'End_Date',        'Mat',
#              'Inns',         'NO',       'Runs',         'HS',        'Ave',
#                'BF',         'SR',        100.0,         50.0,          0.0,
#                '4s',         '6s'],
#       dtype='object')

# %%
data[['Start_Date',   'End_Date',        'Mat',
             'Inns',         'NO',       'Runs',         'HS',        'Ave',
               'BF',         'SR',        100.0,         50.0,          0.0,
               '4s',         '6s']]=data[['Start_Date',   'End_Date',        'Mat',
             'Inns',         'NO',       'Runs',         'HS',        'Ave',
               'BF',         'SR',        100.0,         50.0,          0.0,
               '4s',         '6s']].astype(int)

# %%
data[["Ave","SR"]]=data[["Ave","SR"]].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        62 non-null     object
#  1   Country     62 non-null     object
#  2   Start_Date  62 non-null     int32
#  3   End_Date    62 non-null     int32
#  4   Mat         62 non-null     int32
#  5   Inns        62 non-null     int32
#  6   NO          62 non-null     int32
#  7   Runs        62 non-null     int32
#  8   HS          62 non-null     int32
#  9   Ave         62 non-null     float64
#  10  BF          62 non-null     int32
#  11  SR          62 non-null     float64
#  12  100.0       62 non-null     int32
#  13  50.0        62 non-null     int32
#  14  0.0         62 non-null     int32
#  15  4s          62 non-null     int32
#  16  6s          62 non-null     int32
# dtypes: float64(2), int32(13), object(2)
# memory usage: 5.2+ KB

# %%
data
# Out:
#             Name Country  Start_Date  End_Date  Mat  Inns  NO  Runs   HS  \
# 0    DG Bradman      AUS        1928      1948   52    80  10  6996  334
# 1      HC Brook      ENG        2022      2023   12    20   1  1181  186
# 2      AC Voges      AUS        2015      2016   20    31   7  1485  269
# 3    RG Pollock       SA        1963      1970   23    41   4  2256  274
# 4    GA Headley       WI        1930      1954   22    40   4  2190  270
# ..           ...     ...         ...       ...  ...   ...  ..   ...  ...
# 57   KD Walters      AUS        1965      1981   74   125  14  5357  250
# 58     GC Smith   ICC/SA        2002      2014  117   205  13  9265  277
# 59  WH Ponsford      AUS        1924      1934   29    48   4  2122  266
# 60    SJ McCabe      AUS        1930      1938   39    62   5  2748  232
# 61   DR Jardine      ENG        1928      1934   22    33   6  1296  127
#
#      Ave     BF    SR  100.0  50.0  0.0    4s  6s
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.groupby("Country").count()["Name"]
# Out:
# Country
# AUS        16
# ENG        13
# ICC/IND     2
# ICC/PAK     1
# ICC/SA      2
# ICC/WI      1
# IND         4
# NZ          2
# PAK         4
# SA          5
# SL          3
# WI          8
# ZIM         1
# Name: Name, dtype: int64

# %%
data["Country"].replace("ICC/","",regex=True,inplace=True)

# %%
plt.bar(x=data.groupby("Country").count().index,height=data.groupby("Country").count()["Name"])
# Out:
# <BarContainer object of 9 artists>
